# %% [markdown]
# # Analyzing virtual tfSF using the principles of Information Bottleneck (Simulation 1)
#
# In this notebook we re-run a simulation similar to Simulation 8.1 using a higher number of data samples.

# %% [markdown]
# ## Setup
#
# We start by importing some libraries:

# %%
import numpy as np
import joblib
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.stats import linregress

import tfSF
import npSF

import data.data_creation as D
from IT import IT

# %% [markdown]
# We define the parameters of our simulation:

# %%
learned_features = 2
n_samples = 100
n_epochs = 200

IT_bins=30

# %% [markdown]
# We define a couple of helper functions: a simple linear regression function and a helper function to compute the tfSF learned representation as a function of the weights. Notice that here, for simplicity, we call the steps of SF implemented using *numpy*; since no learning is now required, using *numpy* saves us the overhead of instantiating a *tensorflow* model.

# %%
def linreg(x,y):
    a, b, _, _, _ = stats.linregress(x,y)
    return a*x+b
    

def computeZ(X,W):
    WX = np.dot(W,X.T)
    F = npSF.softabsolute(WX)
    Fsquish, _ = npSF.l2row(F)
    Fhat, _ = npSF.l2row(Fsquish.T)
    Z = Fhat
    return Z

# %% [markdown]
# ## Simulation 1
#
# We now train a SF module and we evaluate the mutual information wrt to different possible labelling of the data. Specifically, we load random data togethere with three possible labelling: *Gaussian, radial, random*.

# %%
X, Y_gaussian, Y_radial, Y_random = D.get_samples_virtualSF(n_samples=n_samples)

# %% [markdown]
# We plot the data to provide an understanding of the data points and the labels.

# %%
labels = [Y_gaussian, Y_radial, Y_random]
titles = ['Gaussian labelling', 'Radial labelling', 'Random labelling']
_, ax = plt.subplots(1,3,figsize=(12,4))

for i in range(len(labels)):
    ax[i].axhline(0,color='black')
    ax[i].axvline(0,color='black')
    ax[i].grid(True)
    ax[i].scatter(X[:,0],X[:,1], c=labels[i])
    ax[i].set_title(titles[i])

# %% [markdown]
# We train the SF module.

# %%
tfsf = tfSF.SFilter(n_features=learned_features)
tfsf.fit(X, epochs=n_epochs, batchsize=n_samples*2)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 3ms/step - loss: 253.1685
# Epoch 2/200
# 1/1 [==============================] - 0s 3ms/step - loss: 252.5923
# Epoch 3/200
# 1/1 [==============================] - 0s 2ms/step - loss: 246.0824
# Epoch 4/200
# 1/1 [==============================] - 0s 2ms/step - loss: 249.4445
# Epoch 5/200
# 1/1 [==============================] - 0s 5ms/step - loss: 250.4906
# Epoch 6/200
# 1/1 [==============================] - 0s 3ms/step - loss: 249.1552
# Epoch 7/200
# 1/1 [==============================] - 0s 2ms/step - loss: 247.7216
# Epoch 8/200
# 1/1 [==============================] - 0s 6ms/step - loss: 247.9732
# Epoch 9/200
# 1/1 [==============================] - 0s 4ms/step - loss: 248.3842
# Epoch 10/200
# 1/1 [==============================] - 0s 4ms/step - loss: 248.2600
# Epoch 11/200
# 1/1 [==============================] - 0s 3ms/step - loss: 247.4790
# Epoch 12/200
# 1/1 [==============================] - 0s 2ms/step - loss: 246.6375
# Epoch 13/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.8281
# Epoch 14/200
# 1/1 [==============================] - 0s 16ms/step - loss: 245.9620
# Epoch 15/200
# 1/1 [==============================] - 0s 2ms/step - loss: 246.9383
# Epoch 16/200
# 1/1 [==============================] - 0s 4ms/step - loss: 246.9280
# Epoch 17/200
# 1/1 [==============================] - 0s 4ms/step - loss: 246.5687
# Epoch 18/200
# 1/1 [==============================] - 0s 4ms/step - loss: 246.4666
# Epoch 19/200
# 1/1 [==============================] - 0s 5ms/step - loss: 246.0339
# Epoch 20/200
# 1/1 [==============================] - 0s 5ms/step - loss: 245
200
# 1/1 [==============================] - 0s 4ms/step - loss: 245.5866
# Epoch 124/200
# 1/1 [==============================] - 0s 5ms/step - loss: 245.5589
# Epoch 125/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.5781
# Epoch 126/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5924
# Epoch 127/200
# 1/1 [==============================] - 0s 4ms/step - loss: 245.6157
# Epoch 128/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5749
# Epoch 129/200
# 1/1 [==============================] - 0s 4ms/step - loss: 245.5903
# Epoch 130/200
# 1/1 [==============================] - 0s 4ms/step - loss: 245.5551
# Epoch 131/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5569
# Epoch 132/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5555
# Epoch 133/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.5569
# Epoch 134/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.5737
# Epoch 135/200
# 1/1 [==============================] - 0s 5ms/step - loss: 245.5627
# Epoch 136/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.5672
# Epoch 137/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.5696
# Epoch 138/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.5584
# Epoch 139/200
# 1/1 [==============================] - ETA: 0s - loss: 245.566 - 0s 2ms/step - loss: 245.5662
# Epoch 140/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5565
# Epoch 141/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5522
# Epoch 142/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5773
# Epoch 143/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5897
# Epoch 144/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.6030
# Epoch 145/200
# 1/1 [==============================] - 0s 4ms/step - loss: 245.5633
# Epoch 146/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.6329
# Epoch 147/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5551
# Epoch 148/200
# 1/1 [==============================] - 0s 4ms/step - loss: 245.6035
# Epoch 149/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.5885
# Epoch 150/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5533
# Epoch 151/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.6544
# Epoch 152/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.5870
# Epoch 153/200
# 1/1 [==============================] - 0s 4ms/step - loss: 245.6675
# Epoch 154/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.6497
# Epoch 155/200
# 1/1 [==============================] - 0s 8ms/step - loss: 245.5740
# Epoch 156/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.6958
# Epoch 157/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.5527
# Epoch 158/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.6511
# Epoch 159/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.6977
# Epoch 160/200
# 1/1 [==============================] - 0s 4ms/step - loss: 245.5828
# Epoch 161/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.7432
# Epoch 162/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.6963
# Epoch 163/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.6424
# Epoch 164/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.7625
# Epoch 165/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.6612
# Epoch 166/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5528
# Epoch 167/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.7124
# Epoch 168/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5645
# Epoch 169/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.6515
# Epoch 170/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.7608
# Epoch 171/200
# 1/1 [==============================] - 0s 4ms/step - loss: 245.6385
# Epoch 172/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.5703
# Epoch 173/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.6647
# Epoch 174/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5771
# Epoch 175/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.6499
# Epoch 176/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.6400
# Epoch 177/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5558
# Epoch 178/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.6739
# Epoch 179/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5600
# Epoch 180/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5781
# Epoch 181/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5844
# Epoch 182/200
# 1/1 [==============================] - 0s 4ms/step - loss: 245.5696
# Epoch 183/200
# 1/1 [==============================] - 0s 5ms/step - loss: 245.5730
# Epoch 184/200
# 1/1 [==============================] - 0s 5ms/step - loss: 245.5561
# Epoch 185/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5804
# Epoch 186/200
# 1/1 [==============================] - 0s 7ms/step - loss: 245.5606
# Epoch 187/200
# 1/1 [==============================] - 0s 6ms/step - loss: 245.5856
# Epoch 188/200
# 1/1 [==============================] - 0s 6ms/step - loss: 245.5620
# Epoch 189/200
# 1/1 [==============================] - 0s 4ms/step - loss: 245.5812
# Epoch 190/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5841
# Epoch 191/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5511
# Epoch 192/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5676
# Epoch 193/200
# 1/1 [==============================] - 0s 4ms/step - loss: 245.5557
# Epoch 194/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.5743
# Epoch 195/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5556
# Epoch 196/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5556
# Epoch 197/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.5605
# Epoch 198/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5811
# Epoch 199/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.6169
# Epoch 200/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.5862

# %% [markdown]
# We plot the loss function to verify that the model converged to a solution.

# %%
plt.title('Loss'); 
plt.xlabel('Epochs'); 
plt.ylabel('L1 loss');
    
plt.plot(tfsf.hist.history['loss'])

# %% [markdown]
# We compute the mutual information of the learned representations and the different types of labelling.

# %%
Ws = tfsf.weights

MI_gaussian = []; MI_radial = []; MI_random = []
  
for W in Ws:
    Z = computeZ(X,W)
    
    MI_gaussian.append(IT.compute_MI_dd_bin(Z,Y_gaussian,n_bins=IT_bins))
    MI_radial.append(IT.compute_MI_dd_bin(Z,Y_radial,n_bins=IT_bins))
    MI_random.append(IT.compute_MI_dd_bin(Z,Y_random,n_bins=IT_bins))

# %% [markdown]
# We plot entropy and mutual information.

# %%
mis = [MI_gaussian, MI_radial, MI_random]
titles = ['Gaussian labelling', 'Radial labelling', 'Random labelling']

for i in range(len(mis)):
    plt.plot(mis[i],label=titles[i])
plt.legend()

# %% [markdown]
# ## Conclusions
#
# - Results on MI seems to hold even more strongly for large data sets.

# %% [markdown]
# ### References
#
# [1] Zennaro, F.M. and Chen, K., 2019. Towards Further Understanding of Sparse Filtering via Information Bottleneck. arXiv preprint arXiv:1910.08964.
