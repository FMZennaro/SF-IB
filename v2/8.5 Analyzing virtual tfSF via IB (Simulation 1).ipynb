# %% [markdown]
# # Analyzing virtual tfSF using the principles of Information Bottleneck (Simulation 1)
#
# In this notebook we re-run a simulation similar to Simulation 8.1 using labelling with different degrees of noise.

# %% [markdown]
# ## Setup
#
# We start by importing some libraries:

# %%
import numpy as np
import joblib
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.stats import linregress

import tfSF
import npSF

import data.data_creation as D
from IT import IT

# %% [markdown]
# We define the parameters of our simulation:

# %%
learned_features = 2
n_samples = 100
n_epochs = 200

IT_bins=30

# %% [markdown]
# We define a couple of helper functions: a simple linear regression function and a helper function to compute the tfSF learned representation as a function of the weights. Notice that here, for simplicity, we call the steps of SF implemented using *numpy*; since no learning is now required, using *numpy* saves us the overhead of instantiating a *tensorflow* model.

# %%
def linreg(x,y):
    a, b, _, _, _ = stats.linregress(x,y)
    return a*x+b
    

def computeZ(X,W):
    WX = np.dot(W,X.T)
    F = npSF.softabsolute(WX)
    Fsquish, _ = npSF.l2row(F)
    Fhat, _ = npSF.l2row(Fsquish.T)
    Z = Fhat
    return Z

# %% [markdown]
# ## Simulation 1
#
# We now train a SF module and we evaluate the mutual information wrt to different possible labelling of the data. Specifically, we load random data togethere with three possible labelling: *Gaussian, radial, random*.

# %%
X, Y_radial, Y_noised = D.get_samples_virtualSF_noise(n_samples=n_samples)

# %% [markdown]
# We plot the data to provide an understanding of the data points and the labels.

# %%
labels = [Y_radial, Y_noised['0.1'], Y_noised['0.2'], Y_noised['0.4']]
titles = ['Radial labelling', 'Radial labelling (noise=0.1)', 'Radial labelling (noise=0.3)', 'Radial labelling (noise=0.5)']
_, ax = plt.subplots(1,4,figsize=(15,4))

for i in range(len(labels)):
    ax[i].axhline(0,color='black')
    ax[i].axvline(0,color='black')
    ax[i].grid(True)
    ax[i].scatter(X[:,0],X[:,1], c=labels[i])
    ax[i].set_title(titles[i])

# %% [markdown]
# We train the SF module.

# %%
tfsf = tfSF.SFilter(n_features=learned_features)
tfsf.fit(X, epochs=n_epochs, batchsize=n_samples*2)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 3ms/step - loss: 274.9865
# Epoch 2/200
# 1/1 [==============================] - 0s 3ms/step - loss: 261.3495
# Epoch 3/200
# 1/1 [==============================] - 0s 3ms/step - loss: 268.0287
# Epoch 4/200
# 1/1 [==============================] - 0s 7ms/step - loss: 264.9804
# Epoch 5/200
# 1/1 [==============================] - 0s 5ms/step - loss: 260.6589
# Epoch 6/200
# 1/1 [==============================] - 0s 4ms/step - loss: 259.5797
# Epoch 7/200
# 1/1 [==============================] - 0s 4ms/step - loss: 263.2848
# Epoch 8/200
# 1/1 [==============================] - 0s 2ms/step - loss: 264.3645
# Epoch 9/200
# 1/1 [==============================] - 0s 2ms/step - loss: 263.7895
# Epoch 10/200
# 1/1 [==============================] - 0s 2ms/step - loss: 262.3522
# Epoch 11/200
# 1/1 [==============================] - 0s 2ms/step - loss: 260.1164
# Epoch 12/200
# 1/1 [==============================] - 0s 2ms/step - loss: 257.3729
# Epoch 13/200
# 1/1 [==============================] - 0s 1ms/step - loss: 253.7451
# Epoch 14/200
# 1/1 [==============================] - 0s 3ms/step - loss: 251.4030
# Epoch 15/200
# 1/1 [==============================] - 0s 2ms/step - loss:
200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5152
# Epoch 125/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5157
# Epoch 126/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5168
# Epoch 127/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5166
# Epoch 128/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5165
# Epoch 129/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5150
# Epoch 130/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5177
# Epoch 131/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5179
# Epoch 132/200
# 1/1 [==============================] - ETA: 0s - loss: 245.518 - 0s 1ms/step - loss: 245.5180
# Epoch 133/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.5154
# Epoch 134/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5164
# Epoch 135/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5165
# Epoch 136/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5163
# Epoch 137/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5154
# Epoch 138/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5154
# Epoch 139/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5159
# Epoch 140/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5164
# Epoch 141/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5160
# Epoch 142/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5151
# Epoch 143/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5152
# Epoch 144/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5156
# Epoch 145/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5161
# Epoch 146/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5148
# Epoch 147/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5170
# Epoch 148/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5159
# Epoch 149/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5162
# Epoch 150/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5222
# Epoch 151/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5171
# Epoch 152/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5202
# Epoch 153/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5227
# Epoch 154/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5208
# Epoch 155/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5170
# Epoch 156/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5188
# Epoch 157/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5190
# Epoch 158/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5162
# Epoch 159/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5183
# Epoch 160/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5154
# Epoch 161/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5184
# Epoch 162/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5157
# Epoch 163/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.5170
# Epoch 164/200
# 1/1 [==============================] - 0s 4ms/step - loss: 245.5206
# Epoch 165/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5185
# Epoch 166/200
# 1/1 [==============================] - 0s 6ms/step - loss: 245.5168
# Epoch 167/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5204
# Epoch 168/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5177
# Epoch 169/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5156
# Epoch 170/200
# 1/1 [==============================] - ETA: 0s - loss: 245.519 - 0s 2ms/step - loss: 245.5197
# Epoch 171/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5194
# Epoch 172/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5199
# Epoch 173/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5169
# Epoch 174/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5166
# Epoch 175/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5215
# Epoch 176/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.5197
# Epoch 177/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5151
# Epoch 178/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5186
# Epoch 179/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5201
# Epoch 180/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5204
# Epoch 181/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.5186
# Epoch 182/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5185
# Epoch 183/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.5202
# Epoch 184/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5246
# Epoch 185/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5262
# Epoch 186/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5172
# Epoch 187/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5197
# Epoch 188/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5222
# Epoch 189/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5188
# Epoch 190/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5186
# Epoch 191/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5186
# Epoch 192/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5155
# Epoch 193/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5204
# Epoch 194/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5217
# Epoch 195/200
# 1/1 [==============================] - 0s 6ms/step - loss: 245.5215
# Epoch 196/200
# 1/1 [==============================] - 0s 3ms/step - loss: 245.5200
# Epoch 197/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5159
# Epoch 198/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5230
# Epoch 199/200
# 1/1 [==============================] - 0s 1ms/step - loss: 245.5269
# Epoch 200/200
# 1/1 [==============================] - 0s 2ms/step - loss: 245.5223

# %% [markdown]
# We plot the loss function to verify that the model converged to a solution.

# %%
plt.title('Loss'); 
plt.xlabel('Epochs'); 
plt.ylabel('L1 loss');
    
plt.plot(tfsf.hist.history['loss'])

# %% [markdown]
# We compute the mutual information of the learned representations and the different types of labelling.

# %%
Ws = tfsf.weights

noises = list(Y_noised.keys())
MIs = np.zeros((len(Ws),len(Y_noised)))
  
for e,W in enumerate(Ws):
    
    Z = computeZ(X,W)
    
    for i in range(len(noises)):
        MIs[e,i] = IT.compute_MI_dd_bin(Z,Y_noised[noises[i]],n_bins=IT_bins)

# %% [markdown]
# We plot entropy and mutual information.

# %%
plt.figure(figsize=(10,8))

for i in range(len(noises)):
    plt.plot(MIs[:,i],label='Noise={0}'.format(noises[i]))
plt.legend()

# %% [markdown]
# ## Conclusions
#
# - MI seems to relate meaningfully to amount of noise.

# %% [markdown]
# ### References
#
# [1] Zennaro, F.M. and Chen, K., 2019. Towards Further Understanding of Sparse Filtering via Information Bottleneck. arXiv preprint arXiv:1910.08964.
